# %%
import mysql.connector as conn

# %%
#pip install mysql-connector-python

# %%
#pip install mysql-connector

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import mysql.connector
version = mysql.connector.__version__

# %%
print(f"Version ={version}")
# Out:
# Version =8.0.32

# %%
myconn = conn.connect(host='localhost', user='bhagyalaxmi', passwd='root')

# %%
myconn

# %%
cursor = myconn.cursor()

# %%
cursor

# %%
result = cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('db',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
query = 'use world'

cursor.execute(query)

result 
result = cursor.execute(query)
cursor.fetchall()
# Out:
# []

# %%
query ='show tables'
cursor.execute(query)
cursor.fetchall()
# Out:
# [('city',), ('country',), ('countrylanguage',)]

# %%
query = "select * from city"
data = pd.read_sql_query(query,myconn)

# %%
data
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.to_csv('sqlCitydata.csv', index=False)

# %%
query = "select * from country"
data = pd.read_sql_query(query,myconn)

# %%
data.head(2)
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# 1  Afganistan/Afqanestan                               Islamic Emirate
#
#      HeadOfState  Capital Code2
# 0        Beatrix    129.0    AW
# 1  Mohammad Omar      1.0    AF

# %%
query = "select * from countrylanguage"
data = pd.read_sql_query(query,myconn)

# %%
data.shape
# Out:
# (984, 4)

# %%
data
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]

# %%
data[data['CountryCode']=='IND']
# Out:
#     CountryCode   Language IsOfficial  Percentage
# 394         IND      Asami          F         1.5
# 395         IND    Bengali          F         8.2
# 396         IND   Gujarati          F         4.8
# 397         IND      Hindi          T        39.9
# 398         IND    Kannada          F         3.9
# 399         IND  Malajalam          F         3.6
# 400         IND    Marathi          F         7.4
# 401         IND      Orija          F         3.3
# 402         IND    Punjabi          F         2.8
# 403         IND      Tamil          F         6.3
# 404         IND     Telugu          F         7.8
# 405         IND       Urdu          F         5.1

# %%
data.groupby('CountryCode').sum('Percentage')
# Out:
#              Percentage
# CountryCode
# ABW                98.9
# AFG                96.1
# AGO                95.4
# AIA                 0.0
# ALB                99.8
# ...                 ...
# YEM                99.6
# YUG                97.7
# ZAF                98.5
# ZMB                64.9
# ZWE                92.7
#
# [233 rows x 1 columns]

# %% [markdown]
# ## Read selected columns

# %%
query = "select CountryCode,Language from countrylanguage"

# %%
data = pd.read_sql_query(query,myconn)

# %%
data.head(2)
# Out:
#   CountryCode Language
# 0         ABW    Dutch
# 1         ABW  English

# %%
data['Language'].unique()
# Out:
# array(['Dutch', 'English', 'Papiamento', 'Spanish', 'Balochi', 'Dari',
#        'Pashto', 'Turkmenian', 'Uzbek', 'Ambo', 'Chokwe', 'Kongo',
#        'Luchazi', 'Luimbe-nganguela', 'Luvale', 'Mbundu',
#        'Nyaneka-nkhumbi', 'Ovimbundu', 'Albaniana', 'Greek', 'Macedonian',
#        'Catalan', 'French', 'Portuguese', 'Arabic', 'Hindi',
#        'Indian Languages', 'Italian', 'Armenian', 'Azerbaijani', 'Samoan',
#        'Tongan', 'Creole English', 'Canton Chinese', 'German',
#        'Serbo-Croatian', 'Vietnamese', 'Czech', 'Hungarian', 'Polish',
#        'Romanian', 'Slovene', 'Turkish', 'Lezgian', 'Russian', 'Kirundi',
#        'Swahili', 'Adja', 'Aizo', 'Bariba', 'Fon', 'Ful', 'Joruba',
#        'Somba', 'Busansi', 'Dagara', 'Dyula', 'Gurma', 'Mossi', 'Bengali',
#        'Chakma', 'Garo', 'Khasi', 'Marma', 'Santhali', 'Tripuri',
#        'Bulgariana', 'Romani', 'Creole French', 'Belorussian',
#        'Ukrainian', 'Garifuna', 'Maya Languages', 'Aimará', 'Guaraní',
# ...

# %%
list(data['Language'].unique())
# Out:
# ['Dutch',
#  'English',
#  'Papiamento',
#  'Spanish',
#  'Balochi',
#  'Dari',
#  'Pashto',
#  'Turkmenian',
#  'Uzbek',
#  'Ambo',
#  'Chokwe',
#  'Kongo',
#  'Luchazi',
#  'Luimbe-nganguela',
#  'Luvale',
#  'Mbundu',
#  'Nyaneka-nkhumbi',
#  'Ovimbundu',
#  'Albaniana',
#  'Greek',
#  'Macedonian',
#  'Catalan',
#  'French',
#  'Portuguese',
#  'Arabic',
#  'Hindi',
#  'Indian Languages',
#  'Italian',
#  'Armenian',
#  'Azerbaijani',
#  'Samoan',
#  'Tongan',
#  'Creole English',
#  'Canton Chinese',
#  'German',
#  'Serbo-Croatian',
#  'Vietnamese',
#  'Czech',
#  'Hungarian',
#  'Polish',
#  'Romanian',
#  'Slovene',
#  'Turkish',
#  'Lezgian',
#  'Russian',
#  'Kirundi',
#  'Swahili',
#  'Adja',
#  'Aizo',
#  'Bariba',
#  'Fon',
#  'Ful',
#  'Joruba',
#  'Somba',
#  'Busansi',
#  'Dagara',
#  'Dyula',
#  'Gurma',
#  'Mossi',
#  'Bengali',
#  'Chakma',
#  'Garo',
#  'Khasi',
#  'Marma',
#  'Santhali',
#  'Tripuri',
#  'Bulgariana',
#  'Romani',
#  'Creole French',
# ...

# %%
data['Language'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           Dutch
# 1         English
# 2      Papiamento
# 3         Spanish
# 4         Balochi
#           ...
# 979        Tongan
# 980       English
# 981       Ndebele
# 982        Nyanja
# 983         Shona
# Name: Language, Length: 984, dtype: object>

# %%
len(list(data['Language'].unique()))
# Out:
# 457

# %% [markdown]
# ### Extract unique values from table column

# %%
query = "select distinct CountryCode from countrylanguage"
data = pd.read_sql_query(query,myconn)
data
# Out:
#     CountryCode
# 0           ABW
# 1           AFG
# 2           AGO
# 3           AIA
# 4           ALB
# ..          ...
# 228         YEM
# 229         YUG
# 230         ZAF
# 231         ZMB
# 232         ZWE
#
# [233 rows x 1 columns]

# %%
data['CountryCode'].value_counts()
# Out:
# CountryCode
# ABW    1
# PAN    1
# NER    1
# NFK    1
# NGA    1
#       ..
# GRC    1
# GRD    1
# GRL    1
# GTM    1
# ZWE    1
# Name: count, Length: 233, dtype: int64

# %%
data.columns
# Out:
# Index(['CountryCode'], dtype='object')

# %%
query = "select * from countrylanguage where isofficial = 'T'"
data = pd.read_sql_query(query, myconn)
data
# Out:
#     CountryCode   Language IsOfficial  Percentage
# 0           ABW      Dutch          T         5.3
# 1           AFG       Dari          T        32.1
# 2           AFG     Pashto          T        52.4
# 3           AIA    English          T         0.0
# 4           ALB  Albaniana          T        97.9
# ..          ...        ...        ...         ...
# 233         ZAF  Afrikaans          T        14.3
# 234         ZAF    English          T         8.5
# 235         ZAF      Xhosa          T        17.7
# 236         ZAF       Zulu          T        22.7
# 237         ZWE    English          T         2.2
#
# [238 rows x 4 columns]

# %%
data['IsOfficial'].unique()
# Out:
# array(['T'], dtype=object)

# %% [markdown]
# ### extract records based on mathematical conditions

# %%
query = "select * from countrylanguage where percentage >75"
data = pd.read_sql_query(query,myconn)
data
# Out:
#     CountryCode        Language IsOfficial  Percentage
# 0           ABW      Papiamento          F        76.7
# 1           ALB       Albaniana          T        97.9
# 2           ANT      Papiamento          T        86.2
# 3           ARG         Spanish          T        96.8
# 4           ARM        Armenian          T        93.4
# ..          ...             ...        ...         ...
# 118         VEN         Spanish          T        96.9
# 119         VIR         English          T        81.7
# 120         VNM      Vietnamese          T        86.8
# 121         YEM          Arabic          T        99.6
# 122         YUG  Serbo-Croatian          T        75.2
#
# [123 rows x 4 columns]

# %%
query = "select * from countrylanguage where percentage >75 and IsOfficial='T'"
data = pd.read_sql_query(query,myconn)
data
# Out:
#    CountryCode        Language IsOfficial  Percentage
# 0          ALB       Albaniana          T        97.9
# 1          ANT      Papiamento          T        86.2
# 2          ARG         Spanish          T        96.8
# 3          ARM        Armenian          T        93.4
# 4          ASM          Samoan          T        90.6
# ..         ...             ...        ...         ...
# 89         VEN         Spanish          T        96.9
# 90         VIR         English          T        81.7
# 91         VNM      Vietnamese          T        86.8
# 92         YEM          Arabic          T        99.6
# 93         YUG  Serbo-Croatian          T        75.2
#
# [94 rows x 4 columns]

# %%
query = "select distinct(CountryCode) from countrylanguage where percentage >75 or IsOfficial='T'"
data = pd.read_sql_query(query,myconn)
data
# Out:
#     CountryCode
# 0           ABW
# 1           AFG
# 2           AIA
# 3           ALB
# 4           AND
# ..          ...
# 201         WSM
# 202         YEM
# 203         YUG
# 204         ZAF
# 205         ZWE
#
# [206 rows x 1 columns]

# %%
query = "select * from city where CountryCode ='IND' and  Name ='Delhi'"
data = pd.read_sql_query(query,myconn)
data
# Out:
#      ID   Name CountryCode District  Population
# 0  1025  Delhi         IND    Delhi     7206704

# %%
cityList=['Delhi', 'Mumbai', 'Gujarat','Haryana']
query = f"select * from city where   CountryCode ='IND' and  Name in {tuple(cityList)}"

# query = "select * from city where CountryCode='IND'"
data = pd.read_sql_query(query,myconn)
data
# Out:
#      ID   Name CountryCode District  Population
# 0  1025  Delhi         IND    Delhi     7206704
