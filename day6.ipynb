# %%
import pandas as pd

# %%
# if not installed, open anaconda prompt, use this command pip install pandas and press enter
# after installing package restart the kernel

# %%
data = pd.read_csv("addresses.csv")

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
pwd() # to check current file path
# Out:
# 'C:\\Users\\Mona'

# %%
data1 = pd.read_csv("locations.csv")

# %%
data1
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# ...

# %%
data.shape     # for address.csv file
# Out:
# (21, 8)

# %%
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
data.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              21 non-null     int64
#  1   location_id     21 non-null     int64
#  2   address_1       21 non-null     object
#  3   address_2       2 non-null      object
#  4   city            21 non-null     object
#  5   state_province  21 non-null     object
#  6   postal_code     21 non-null     object
#  7   country         21 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 1.4+ KB

# %%
data.describe()
# Out:
#               id  location_id
# count  21.000000    21.000000
# mean   11.000000    11.095238
# std     6.204837     6.363213
# min     1.000000     1.000000
# 25%     6.000000     6.000000
# 50%    11.000000    11.000000
# 75%    16.000000    16.000000
# max    21.000000    22.000000

# %%
data['address_1']
# Out:
# 0          2600 Middlefield Road
# 1               24 Second Avenue
# 2               24 Second Avenue
# 3               24 Second Avenue
# 4               24 Second Avenue
# 5              800 Middle Avenue
# 6                 500 Arbor Road
# 7              800 Middle Avenue
# 8          2510 Middlefield Road
# 9          1044 Middlefield Road
# 10           2140 Euclid Avenue.
# 11         1044 Middlefield Road
# 12           399 Marine Parkway.
# 13            660 Veterans Blvd.
# 14          1500 Valencia Street
# 15           1161 South Bernardo
# 16       409 South Spruce Avenue
# 17              114 Fifth Avenue
# 18           19 West 39th Avenue
# 19            123 El Camino Real
# 20    2013 Avenue of the fellows
# Name: address_1, dtype: object

# %%
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
data[['address_2', 'city', 'state_province']]
# Out:
#     address_2                 city state_province
# 0         NaN         Redwood City             CA
# 1         NaN            San Mateo             CA
# 2         NaN            San Mateo             CA
# 3         NaN            San Mateo             CA
# 4         NaN            San Mateo             CA
# 5         NaN           Menlo Park             CA
# 6         NaN           Menlo Park             CA
# 7         NaN           Menlo Park             CA
# 8         NaN         Redwood City             CA
# 9         NaN         Redwood City             CA
# 10        NaN         Redwood City             CA
# 11  2nd Floor         Redwood City             CA
# 12        NaN         Redwood City             CA
# 13        NaN         Redwood City             CA
# 14        NaN        San Francisco             CA
# 15        NaN            Sunnyvale             CA
# 16        NaN  South San Francisco             CA
# 17        NaN         Redwood City             CA
# ...

# %%
data[['address_2', 'city', 'state_province']].head()
# Out:
#   address_2          city state_province
# 0       NaN  Redwood City             CA
# 1       NaN     San Mateo             CA
# 2       NaN     San Mateo             CA
# 3       NaN     San Mateo             CA
# 4       NaN     San Mateo             CA

# %%
data[['address_2', 'city', 'state_province']].head(2)
# Out:
#   address_2          city state_province
# 0       NaN  Redwood City             CA
# 1       NaN     San Mateo             CA

# %%
data[['address_2', 'city', 'state_province']].tail()
# Out:
#     address_2                 city state_province
# 16        NaN  South San Francisco             CA
# 17        NaN         Redwood City             CA
# 18        NaN            San Mateo             CA
# 19        NaN              Belmont             CA
# 20  Suite 100        San Francisco             CA

# %%
data[['address_2', 'city', 'state_province']].tail(2)
# Out:
#     address_2           city state_province
# 19        NaN        Belmont             CA
# 20  Suite 100  San Francisco             CA

# %%
data1 = pd.read_csv("addresses.csv", header = None, names = [1,2,3,4,5,6,7,8])

# %%
data1.head()
# Out:
#     1            2                      3          4             5  \
# 0  id  location_id              address_1  address_2          city
# 1   1            1  2600 Middlefield Road        NaN  Redwood City
# 2   2            2       24 Second Avenue        NaN     San Mateo
# 3   3            3       24 Second Avenue        NaN     San Mateo
# 4   4            4       24 Second Avenue        NaN     San Mateo
#
#                 6            7        8
# 0  state_province  postal_code  country
# 1              CA        94063       US
# 2              CA        94401       US
# 3              CA        94403       US
# 4              CA        94401       US

# %%
data1.to_excel("myAddress.xlsx", index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 data1.to_excel("myAddress.xlsx", index = False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2252, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options)
#    2239 from pandas.io.formats.excel import ExcelFormatter
#    2241 formatter = ExcelFormatter(
#    2242     df,
#    2243     na_rep=na_rep,
#    (...)
#    2250     inf_rep=inf_rep,
#    2251 )
# -> 2252 formatter.write(
#    2253     excel_writer,
#    2254     sheet_name=sheet_name,
#    2255     startrow=startrow,
#    2256     startcol=startcol,
#    2257     freeze_panes=freeze_panes,
#    2258     engine=engine,
#    2259     storage_options=storage_options,
#    2260 )
#
# ...

# %%
data1.to_csv("myAddress.csv", index = False)

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = pd.read_csv("https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv")

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/phones.csv")
# Out:
#     id  contact_id  location_id  organization_id  service_id  country_prefix  \
# 0    1         NaN          1.0              NaN         NaN             NaN
# 1    2         NaN          1.0              NaN         NaN             NaN
# 2    3         NaN          2.0              NaN         NaN             NaN
# 3    4         NaN          2.0              NaN         NaN             NaN
# 4    5         NaN          3.0              NaN         NaN             NaN
# 5    6         NaN          3.0              NaN         NaN             NaN
# 6    7         NaN          4.0              NaN         NaN             NaN
# 7    8         NaN          4.0              NaN         NaN             NaN
# 8    9         NaN          5.0              NaN         NaN             NaN
# 9   10         NaN          5.0              NaN         NaN             NaN
# 10  11         NaN          6.0              NaN         NaN             NaN
# ...

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data[['PassengerId','Survived','Fare']].describe()
# Out:
#        PassengerId    Survived        Fare
# count   891.000000  891.000000  891.000000
# mean    446.000000    0.383838   32.204208
# std     257.353842    0.486592   49.693429
# min       1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    7.910400
# 50%     446.000000    0.000000   14.454200
# 75%     668.500000    1.000000   31.000000
# max     891.000000    1.000000  512.329200

# %%
data[['Name','Embarked','Ticket']].describe()
# Out:
#                            Name Embarked  Ticket
# count                       891      889     891
# unique                      891        3     681
# top     Braund, Mr. Owen Harris        S  347082
# freq                          1      644       7

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.dtypes[data.dtypes == 'int64']
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# dtype: object

# %%
data.dtypes[data.dtypes == 'int64'].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
list(data.dtypes[data.dtypes == 'int64'].index)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch']

# %%
list(data.dtypes[data.dtypes == 'float64'].index)
# Out:
# ['Age', 'Fare']

# %%
list(data.dtypes[data.dtypes == 'object'].index)
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
colList = list(data.dtypes[data.dtypes == 'object'].index)
colList
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
data[colList]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
colIntList = data.dtypes[data.dtypes == 'int64'].index
data[colIntList]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
colFloatList = data.dtypes[data.dtypes == 'float64'].index
data[colFloatList]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
colObjList = data.dtypes[data.dtypes == 'object'].index
data[colObjList]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[data['Embarked']=='S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
data[data['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data[data['Survived']== 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[data['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
filter1 = data['Survived'] == 0

# %%
filter1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Survived, Length: 891, dtype: bool

# %%
filter2 = data['Sex'] == 'male'
filter2
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
data[filter1 & filter2]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data[filter1 & filter2].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
len(data[filter1 & filter2])
# Out:
# 468

# %%
data[(data['Survived'] == 0) & (data['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
len(data[(data['Survived']==0) & (data['Sex'] == 'male')])
# Out:
# 468

# %%
len(data[(data['Survived']==0) | (data['Sex']=='male')])
# Out:
# 658

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
list(data['Embarked'].unique())
# Out:
# ['S', 'C', 'Q', nan]

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data[data['Fare'] == max(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
data[data['Fare']==min(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
len(data[data['Fare']==min(data['Fare'])])
# Out:
# 15

# %%
temp = (data[data['Fare']==min(data['Fare'])])

# %%
type(temp)
# Out:
# pandas.core.frame.DataFrame

# %%
data[data['Cabin'].isnull()==False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[data['Cabin'].isnull()==False].value_counts
# Out:
# <bound method DataFrame.value_counts of      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %%
data['newColumn']='India'

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['newColumn2'] =data['Fare']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked newColumn  newColumn2
# 0      0         A/5 21171   7.2500   NaN        S     India      7.2500
# 1      0          PC 17599  71.2833   C85        C     India     71.2833
# 2      0  STON/O2. 3101282   7.9250   NaN        S     India      7.9250
# ...

# %%
data['newColumn3']=data['Age']*data['Fare']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked newColumn  newColumn2  \
# 0      0         A/5 21171   7.2500   NaN        S     India      7.2500
# 1      0          PC 17599  71.2833   C85        C     India     71.2833
# 2      0  STON/O2. 3101282   7.9250   NaN        S     India      7.9250
# ...

# %%
list(data.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'newColumn',
#  'newColumn2',
#  'newColumn3']

# %%
data = data.drop('newColumn', axis=1)

# %%
list(data.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'newColumn2',
#  'newColumn3']

# %%
data.drop(['newColumn2','newColumn3'], axis =1, inplace=True)

# %%
list(data.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.iloc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
data.iat[3,4]
# Out:
# 'female'

# %%
data.iat[2,8]
# Out:
# 'STON/O2. 3101282'

# %%
data.iat[1,3]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
data.loc[2,'Ticket']
# Out:
# 'STON/O2. 3101282'

# %%
data.loc[50:55,'PassengerId':'Sex']
# Out:
#     PassengerId  Survived  Pclass  \
# 50           51         0       3
# 51           52         0       3
# 52           53         1       1
# 53           54         1       2
# 54           55         0       1
# 55           56         1       1
#
#                                                  Name     Sex
# 50                         Panula, Master. Juha Niilo    male
# 51                       Nosworthy, Mr. Richard Cater    male
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female
# 54                     Ostby, Mr. Engelhart Cornelius    male
# 55                                  Woolner, Mr. Hugh    male

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.loc[[1,2,3,8,4,90,80],['PassengerId','Survived','Cabin','Name','Fare']]
# Out:
#     PassengerId  Survived Cabin  \
# 1             2         1   C85
# 2             3         1   NaN
# 3             4         1  C123
# 8             9         1   NaN
# 4             5         0   NaN
# 90           91         0   NaN
# 80           81         0   NaN
#
#                                                  Name     Fare
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                              Heikkinen, Miss. Laina   7.9250
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  11.1333
# 4                            Allen, Mr. William Henry   8.0500
# 90                               Christmann, Mr. Emil   8.0500
# 80                               Waelens, Mr. Achille   9.0000

# %%
temp = data[data['Age']<20]
temp
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                  Rice, Master. Eugene
# ..           ...       ...     ...                                   ...
# 855          856         1       3            Aks, Mrs. Sam (Leah Rosen)
# 869          870         1       3       Johnson, Master. Harold Theodor
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
# 877          878         0       3                  Petroff, Mr. Nedelio
# 887          888         1       1          Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# ...

# %%
list(temp['Age'].unique())
# Out:
# [2.0,
#  14.0,
#  4.0,
#  15.0,
#  8.0,
#  19.0,
#  18.0,
#  3.0,
#  7.0,
#  5.0,
#  11.0,
#  17.0,
#  16.0,
#  0.83,
#  14.5,
#  12.0,
#  9.0,
#  1.0,
#  0.92,
#  10.0,
#  13.0,
#  0.75,
#  6.0,
#  0.67,
#  0.42]

# %%
temp = data[(data['Age'] > 15) & (data['Age']<20)]

# %%
temp
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 38            39         0       3
# 44            45         1       3
# 49            50         0       3
# 67            68         0       3
# ..           ...       ...     ...
# 844          845         0       3
# 853          854         1       1
# 855          856         1       3
# 877          878         0       3
# 887          888         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 27                  Fortune, Mr. Charles Alexander    male  19.0      3
# 38              Vander Planke, Miss. Augusta Maria  female  18.0      2
# 44                   Devaney, Miss. Margaret Delia  female  19.0      0
# 49   Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 67                        Crease, Mr. Ernest James    male  19.0      0
# ..                                             ...     ...   ...    ...
# ...

# %%
temp['Age'].unique()
# Out:
# array([19., 18., 17., 16.])

# %%
len(data[data['Age']==18])
# Out:
# 26

# %%
data.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
data.set_index('Name')
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
temp = data.dropna()

# %%
temp
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
temp = data.fillna(555555)

# %%
temp
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male      22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      38.0
# 2                               Heikkinen, Miss. Laina  female      26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      35.0
# 4                             Allen, Mr. William Henry    male      35.0
# ..                                                 ...     ...       ...
# ...

# %%
temp =data.isna()

# %%
temp
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data.groupby('Cabin').sum('Fare')
# Out:
#        PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# Cabin
# A10            584         0       1  36.0      0      0  40.1250
# A14            476         0       1   0.0      0      0  52.0000
# A16            557         1       1  48.0      1      0  39.6000
# A19            285         0       1   0.0      0      0  26.0000
# A20            600         1       1  49.0      1      0  56.9292
# ...            ...       ...     ...   ...    ...    ...      ...
# F33            930         3       6  87.0      0      0  34.0000
# F38            777         0       3   0.0      0      0   7.7500
# F4             803         2       4   5.0      4      2  78.0000
# G6             864         2      12  59.0      2      5  54.3250
# T              340         0       1  45.0      0      0  35.5000
#
# [147 rows x 7 columns]

# %%
data.groupby(['Sex']).sum('Fare')
# Out:
#         PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       135343       233     678   7286.00    218    204  13966.6628
# male         262043       109    1379  13919.17    248    136  14727.2865

# %%
data.groupby('Sex').sum()['Fare']
# Out:
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
data.groupby('Sex').mean()['Fare']
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
data.groupby('Sex').std()['Fare']
# data['Fare']=data['Fare'].astype(float)
# data['Fare']

# %%
# data.groupby('Sex').std()['Fare']

# %%
# data.groupby('Sex').max()['Fare']

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data.groupby('Embarked').sum()['Fare']
# Out:
# Embarked
# C    10072.2962
# Q     1022.2543
# S    17439.3988
# Name: Fare, dtype: float64

# %%
# data.groupby('Embarked').mean()['Fare']
# data.groupby('Embarked').max()['Fare']
# data.groupby('Embarked').std()['Fare']

# %%
def apply_group(x):
    if x<=100:
        return 'A'
    elif x>100 and x<=200:
        return 'B'
    else:
        return 'C'
    
data['Fare_Group'] = data['Fare'].apply(apply_group)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# data.groupby('Fare_Group').max()['Fare']

# %%
my_dict={
    "key1" : [1,2,3,4,9,8],
    "key2" : [25,36,14,58,69,8],
    "key3" : [96,85,41,25,36,96]
}

# %%
my_dict
# Out:
# {'key1': [1, 2, 3, 4, 9, 8],
#  'key2': [25, 36, 14, 58, 69, 8],
#  'key3': [96, 85, 41, 25, 36, 96]}

# %%
df1 = pd.DataFrame(my_dict)

# %%
df1
# Out:
#    key1  key2  key3
# 0     1    25    96
# 1     2    36    85
# 2     3    14    41
# 3     4    58    25
# 4     9    69    36
# 5     8     8    96

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = {
    "key1":[1, 2, 3, 4, 9, 8,9],
    "key2":[98,65,12,0,'Mumbai',96,1],
    "key3":[9,5,4,25,8,9,4]            
}

# %%
df2 = pd.DataFrame(df2)

# %%
df2
# Out:
#    key1    key2  key3
# 0     1      98     9
# 1     2      65     5
# 2     3      12     4
# 3     4       0    25
# 4     9  Mumbai     8
# 5     8      96     9
# 6     9       1     4

# %%
pd.merge(df1,df2,how='outer', on ='key1')
# Out:
#    key1  key2_x  key3_x  key2_y  key3_y
# 0     1      25      96      98       9
# 1     2      36      85      65       5
# 2     3      14      41      12       4
# 3     4      58      25       0      25
# 4     9      69      36  Mumbai       8
# 5     9      69      36       1       4
# 6     8       8      96      96       9
